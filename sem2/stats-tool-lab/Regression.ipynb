# %% [markdown]
# <a href="https://colab.research.google.com/github/navyadua/christu-ug/blob/main/sem2/stats-tool-lab/Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/navyadua/data/main/hotel_booking_demand_perfect.csv')
df
# Out:
#             hotel  is_canceled  ...  adr_standardised  lead_time_normalised
# 0      City Hotel            1  ...         -0.919817              0.576147
# 1      City Hotel            0  ...          0.439106              0.311927
# 2      City Hotel            0  ...         -2.180384              0.055046
# 3      City Hotel            1  ...         -0.935875              0.592661
# 4    Resort Hotel            0  ...          0.041666              0.528440
# ..            ...          ...  ...               ...                   ...
# 434    City Hotel            0  ...          0.348779                   NaN
# 435    City Hotel            0  ...          0.127979                   NaN
# 436  Resort Hotel            0  ...         -1.637016                   NaN
# 437    City Hotel            0  ...         -0.755221                   NaN
# 438    City Hotel            0  ...         -0.674930                   NaN
#
# [439 rows x 33 columns]

# %%
plt.figure(figsize=(10,10))
x = df[['lead_time']]
y =df[['adr']]
plt.scatter(x, y, marker='o')
plt.title('lead time Vs adr')
plt.xlabel('lead time')
plt.ylabel('adr')
plt.show()
#plt.xlim(0,3000)
#plt.ylim(0,450)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
lin_model = LinearRegression()
lin_model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# model evaluation for training set
y_predict = lin_model.predict(x)
rmse = (np.sqrt(mean_squared_error(y, y_predict)))
r2 = r2_score(y, y_predict)

print("The model performance ")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# The model performance
# --------------------------------------
# RMSE is 49.26856342232611
# R2 score is 0.021969649273244185

# %%
print('Model Intercept is {}'.format(lin_model.intercept_))
print('Model Coefficients {}'.format(lin_model.coef_))
# Out:
# Model Intercept is [116.15471418]
# Model Coefficients [[-0.06800542]]

# %%
import seaborn as sns

g = sns.jointplot(x="lead_time", y="adr", data=df, kind='reg')
regline = g.ax_joint.get_lines()[0]
regline.set_color('red')
regline.set_zorder(5)
